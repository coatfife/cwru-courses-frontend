# %%
import numpy as np
import pandas as pd
import plotly.express as px
import plotly.io as pio
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px
import dash
from dash import dcc
from dash import html
from dash import dash_table
from dash.dependencies import Input, Output
from sklearn.linear_model import LinearRegression
import random
from random import gauss
import math
import datetime 
import pymongo

start = datetime.datetime.today()
date = [start.date() - datetime.timedelta(days=x) for x in range(50)]
date = sorted(date,key=lambda x: random.random())
createdby= ["abc153","xyz830","aaa127","bbb234", "ccc345","anon","eee577", "fff678","ggg789","qrs276","abc153","xyz830","anon","bbb234", "ccc347","ddd456","eee567", "fff678","ggg789","qrs286",
           "anon","anon","anon","bbb734", "ccc345","ddd456","eee577", "anon","ggg789","qrs286","abc153","xyz830","aaa123","bbb234", "ccc345","anon","eee567", "fff678","ggg789","qrs286",
           "abc153","xyz730","aaa123","bbb234", "ccc345","ddd456","eee567", "fff678","ggg789","qrs287",]
createdby = sorted(createdby,key=lambda x: random.random())
major = ["Computer Science", "Biomedical Engineering", "Psychology", "Political Science", "Physics", "Economics", 
         "Computer Science", "Biomedical Engineering", "Statistics","Nursing","Computer Science", "Biomedical Engineering", "Psychology", "Political Science", "Physics", "Economics", 
         "Computer Science", "Biomedical Engineering", "Statistics","Nursing","Computer Science", "Biomedical Engineering", "Psychology", "Political Science", "Physics", "Economics", 
         "Computer Science", "Biomedical Engineering", "Spanish","Nursing","Computer Science", "Mathematics", "Psychology", "Political Science", "Physics", "Economics", 
         "Computer Science", "Biomedical Engineering", "Statistics","Nursing","Computer Science", "Biomedical Engineering", "Psychology", "Political Science", "Physics", "Economics", 
         "Computer Science", "Theater", "Statistics","Nursing"]
major = sorted(major,key=lambda x: random.random())
tips = ["attend class", "attend office hours", "review homework", "start project early","attend class","attend class", "attend office hours", "review homework", "start project early","attend class",
       "attend class", "attend office hours", "review homework", "start project early","attend class","attend class", "attend office hours", "review homework", "start project early","attend class",
       "attend class", "attend office hours", "review homework", "start project early","attend class","attend class", "attend office hours", "review homework", "start project early","attend class",
       "attend class", "attend office hours", "review homework", "start project early","attend class","attend class", "attend office hours", "review homework", "start project early","attend class",
       "attend class", "attend office hours", "review homework", "start project early","attend class","attend class", "attend office hours", "review homework", "start project early","attend class"]
tips = sorted(tips,key=lambda x: random.random())
additional_comments = ["i love this class","i hate this class", "huge time commitment", "i love this class", "i love this class","i love this class","i hate this class", "huge time commitment", "i love this class", "i love this class",
                      "i love this class","i hate this class", "huge time commitment", "i love this class", "i love this class","i love this class","i hate this class", "huge time commitment", "i love this class", "i love this class",
                      "i love this class","i hate this class", "huge time commitment", "i love this class", "i love this class","i love this class","i hate this class", "huge time commitment", "i love this class", "i love this class",
                      "i love this class","i hate this class", "huge time commitment", "i love this class", "i love this class","i love this class","i hate this class", "huge time commitment", "i love this class", "i love this class",
                      "i love this class","i hate this class", "huge time commitment", "i love this class", "i love this class","i love this class","i hate this class", "huge time commitment", "i love this class", "i love this class",]
additional_comments = sorted(additional_comments,key=lambda x: random.random())
course_name = ["CSDS132","STAT325","ECON102", "PSCL353","PHYS222","MATH223","CSDS305","MATH122","ECON103","CSDS344","CSDS132","STAT325","ECON102", "PSCL353","PHYS222","MATH223","CSDS305","MATH122","ECON103","CSDS344",
              "CSDS132","STAT325","ECON102", "PSCL353","PHYS222","MATH223","CSDS305","MATH122","ECON103","CSDS344","CSDS132","STAT325","ECON102", "PSCL353","PHYS222","MATH223","CSDS305","MATH122","ECON103","CSDS344",
              "CSDS132","STAT325","ECON102", "PSCL353","PHYS222","MATH223","CSDS305","MATH122","ECON103","CSDS344"]
course_name = sorted(course_name,key=lambda x: random.random())
difficulty = [random.randint(1, 10) for _ in range(50)]
overall = [random.randint(1, 10) for _ in range(50)]
usefulness = [gauss(5, 1) for _ in range(50)]
usefulness = [int(round(x)) for x in usefulness]
dict1 = {'Course Difficulty': difficulty, 'Rating': overall, 'Course Usefulness': usefulness, 'Major':major, 'Date':date, 'Author':createdby,
       'Tips':tips, 'Additional Comments':additional_comments, 'Course Name':course_name}
df1 = pd.DataFrame(dict1)
def anongroup():
    l = []
    for val in df1['Author']:
        if val == "anon":
            l.append('true')
        if val != "anon":
            l.append('false')
    return l

dict = {'Course Difficulty': difficulty, 'Rating': overall, 'Course Usefulness': usefulness, 'Major':major, 'Date':date, 'Author':createdby,
       'Tips':tips, 'Additional Comments':additional_comments, 'Course Name':course_name, 'Is Anonymous':anongroup()}
df = pd.DataFrame(dict)
# def ratingcategory():
#     l = []
#     for val in df['overall_rating']:
#         if val == 1:
#             l.append('low')
#         elif val == 2:
#             l.append('low')        
#         elif val == 3:
#             l.append('low')
#         elif val == 4:
#             l.append('low')
#         elif val == 5:
#             l.append('medium')
#         elif val == 6:
#             l.append('medium')
#         elif val == 7:
#             l.append('medium')
#         elif val == 9:
#             l.append('high')
#         elif val == 8:
#             l.append('high')
#         elif val == 10:
#             l.append('high')
#     return l

df
# Out:
#     Course Difficulty  Rating  Course Usefulness                   Major  \
# 0                   9       1                  5       Political Science
# 1                   4       9                  5              Statistics
# 2                   9       8                  6                 Nursing
# 3                   2       1                  6  Biomedical Engineering
# 4                   7       1                  5  Biomedical Engineering
# 5                  10       4                  6        Computer Science
# 6                   7       3                  5              Psychology
# 7                   5       3                  4       Political Science
# 8                   4       6                  5              Statistics
# 9                   9       9                  6              Statistics
# 10                  9       5                  3  Biomedical Engineering
# 11                  5       6                  5  Biomedical Engineering
# ...

# %%
pio.templates.default = "plotly_white"

fig1 = px.pie(df, names='Major', opacity=0.65,title="Breakdown of Majors")
fig2 = px.scatter(df,x='Rating', y = 'Course Difficulty', opacity=0.65, title = "Overall Rating vs Difficulty", 
                  hover_data=['Course Difficulty','Course Usefulness','Major'],trendline = 'ols', marginal_x= 'box',marginal_y= 'box')
fig3 = px.histogram(df,x='Rating', facet_row = 'Is Anonymous',title = "Overall Rating Distribution by Anonymity Status",color = 'Is Anonymous')
fig4 = px.scatter_3d(df,x='Rating', y = 'Course Difficulty', z = 'Course Usefulness' ,title = 'Difficulty vs Usefulness vs Rating',color = 'Is Anonymous')
fig5 = px.scatter_matrix(df, dimensions=["Course Difficulty", "Rating", "Course Usefulness"], color = 'Is Anonymous', title = 'Relationships Between Review Metrics')
app = dash.Dash(__name__)
colors = {
    'background': '#111111',
    'text': '#7FDBFF'
}
plot_bgcolor=colors['background']
app.layout = html.Div(children=[
        html.Div(
            children=[
                html.H1(
                    children="Course Review Analysis",style={'textAlign': 'left'}, className="header-title" 
                ), #Header title
                html.H3(
                    children="A Look at Data from Course Review Posts",
                    className="header-description", style={'textAlign': 'left'},
                ),
            ],
            className="header",style={},
        ), #Description below the header
        html.Div(
            children=[
                html.Div(
                children = dcc.Graph(
                    id = 'g5',
                    figure = fig5,
                  #  config={"displayModeBar": False},
                ),
                style={'width': '100%', 'display': 'inline-block'},
            ),
               html.Div(
                children = dcc.Graph(
                    id = 'g1',
                    figure = fig1,
                  #  config={"displayModeBar": False},
                ),
                style={'width': '50%', 'display': 'inline-block'},
            ),
                html.Div(
                children = dcc.Graph(
                    id = 'g2',
                    figure = fig2,
                    #config={"displayModeBar": False},
                ),
                style={'width': '50%', 'display': 'inline-block'},
            ),
                html.Div(
                children = dcc.Graph(
                    id = 'g3',
                    figure = fig3,
                    #config={"displayModeBar": False},
                ),
                style={'width': '50%', 'display': 'inline-block'},
            ),
                html.Div(
                children = dcc.Graph(
                    id = 'g4',
                    figure = fig4,
                    #config={"displayModeBar": False},
                ),
                style={'width': '50%', 'display': 'inline-block'},
            ),
                
            ],

        className = 'double-graph',
        )
]
) 



#if not using virtual environment
#dashboard is hosted at http://127.0.0.1:8050/
if __name__ == '__main__':
     app.run_server()
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
